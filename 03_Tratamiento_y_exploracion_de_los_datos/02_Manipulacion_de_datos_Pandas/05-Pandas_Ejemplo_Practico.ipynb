# %% [markdown]
# # Ejemplo Practico para Pandas con DataFrames

# %% [markdown]
# ## 1. Inspeccion Inicial del DataFrame

# %%
# Importacion de Librerias
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Importacion de Librerias
# ----> 2 import pandas as pd
#
# File c:\Repositorios\AnaliticaDeDatosParaNegociosDigitales\03_Tratamiento_y_exploracion_de_los_datos\02_Manipulacion_de_datos_Pandas\.venv\Lib\site-packages\pandas\__init__.py:26
#      24 for _dependency in _hard_dependencies:
#      25     try:
# ---> 26         __import__(_dependency)
#      27     except ImportError as _e:  # pragma: no cover
#      28         _missing_dependencies.append(f"{_dependency}: {_e}")
#
# File c:\Repositorios\AnaliticaDeDatosParaNegociosDigitales\03_Tratamiento_y_exploracion_de_los_datos\02_Manipulacion_de_datos_Pandas\.venv\Lib\site-packages\numpy\__init__.py:125
#     122 from . import _distributor_init
#     124 try:
# --> 125     from numpy.__config__ import show_config
#     126 except ImportError as e:
#     127     msg = """Error importing numpy: you should not try to import numpy from
#     128     its source directory; please exit the numpy source tree, and relaunch
#     129     your python interpreter from there."""
#
# File c:\Repositorios\AnaliticaDeDatosParaNegociosDigitales\03_Tratamiento_y_exploracion_de_los_datos\02_Manipulacion_de_datos_Pandas\.venv\Lib\site-packages\numpy\__config__.py:4
#       1 # This file is generated by numpy's build process
#       2 # It contains system_info results at the time of building this package.
#       3 from enum import Enum
# ----> 4 from numpy._core._multiarray_umath import (
#       5     __cpu_features__,
#       6     __cpu_baseline__,
#       7     __cpu_dispatch__,
#       8 )
#      10 __all__ = ["show_config"]
#      11 _built_with_meson = True
#
# File c:\Repositorios\AnaliticaDeDatosParaNegociosDigitales\03_Tratamiento_y_exploracion_de_los_datos\02_Manipulacion_de_datos_Pandas\.venv\Lib\site-packages\numpy\_core\__init__.py:74
#      71 from .numerictypes import sctypeDict, sctypes
#      73 multiarray.set_typeDict(nt.sctypeDict)
# ---> 74 from . import (
#      75     _machar,
#      76     einsumfunc,
#      77     fromnumeric,
#      78     function_base,
#      79     getlimits,
#      80     numeric,
#      81     shape_base,
#      82 )
#      83 from .einsumfunc import *
#      84 from .fromnumeric import *
#
# File c:\Repositorios\AnaliticaDeDatosParaNegociosDigitales\03_Tratamiento_y_exploracion_de_los_datos\02_Manipulacion_de_datos_Pandas\.venv\Lib\site-packages\numpy\_core\einsumfunc.py:9
#       6 import operator
#       8 from numpy._core.multiarray import c_einsum
# ----> 9 from numpy._core.numeric import asanyarray, tensordot
#      10 from numpy._core.overrides import array_function_dispatch
#      12 __all__ = ['einsum', 'einsum_path']
#
# File c:\Repositorios\AnaliticaDeDatosParaNegociosDigitales\03_Tratamiento_y_exploracion_de_los_datos\02_Manipulacion_de_datos_Pandas\.venv\Lib\site-packages\numpy\_core\numeric.py:13
#      10 import numpy as np
#      11 from numpy.exceptions import AxisError
# ---> 13 from . import multiarray, numerictypes, overrides, shape_base, umath
#      14 from . import numerictypes as nt
#      15 from ._ufunc_config import errstate
#
# File c:\Repositorios\AnaliticaDeDatosParaNegociosDigitales\03_Tratamiento_y_exploracion_de_los_datos\02_Manipulacion_de_datos_Pandas\.venv\Lib\site-packages\numpy\_core\shape_base.py:139
#     135 def _atleast_3d_dispatcher(*arys):
#     136     return arys
# --> 139 @array_function_dispatch(_atleast_3d_dispatcher)
#     140 def atleast_3d(*arys):
#     141     """
#     142     View inputs as arrays with at least three dimensions.
#     143
#    (...)    188
#     189     """
#     190     res = []
#
# File c:\Repositorios\AnaliticaDeDatosParaNegociosDigitales\03_Tratamiento_y_exploracion_de_los_datos\02_Manipulacion_de_datos_Pandas\.venv\Lib\site-packages\numpy\_core\overrides.py:147, in array_function_dispatch.<locals>.decorator(implementation)
#     145 if verify:
#     146     if dispatcher is not None:
# --> 147         verify_matching_signatures(implementation, dispatcher)
#     148     else:
#     149         # Using __code__ directly similar to verify_matching_signature
#     150         co = implementation.__code__
#
# File c:\Repositorios\AnaliticaDeDatosParaNegociosDigitales\03_Tratamiento_y_exploracion_de_los_datos\02_Manipulacion_de_datos_Pandas\.venv\Lib\site-packages\numpy\_core\overrides.py:88, in verify_matching_signatures(implementation, dispatcher)
#      86 """Verify that a dispatcher function has the right signature."""
#      87 implementation_spec = ArgSpec(*getargspec(implementation))
# ---> 88 dispatcher_spec = ArgSpec(*getargspec(dispatcher))
#      90 if (implementation_spec.args != dispatcher_spec.args or
#      91         implementation_spec.varargs != dispatcher_spec.varargs or
#      92         implementation_spec.keywords != dispatcher_spec.keywords or
#    (...)     96          len(implementation_spec.defaults) !=
#      97          len(dispatcher_spec.defaults))):
#      98     raise RuntimeError('implementation and dispatcher for %s have '
#      99                        'different function signatures' % implementation)
#
# File c:\Repositorios\AnaliticaDeDatosParaNegociosDigitales\03_Tratamiento_y_exploracion_de_los_datos\02_Manipulacion_de_datos_Pandas\.venv\Lib\site-packages\numpy\_utils\_inspect.py:111, in getargspec(func)
#     109 if not isfunction(func):
#     110     raise TypeError('arg is not a Python function')
# --> 111 args, varargs, varkw = getargs(func.__code__)
#     112 return args, varargs, varkw, func.__defaults__
#
# File c:\Repositorios\AnaliticaDeDatosParaNegociosDigitales\03_Tratamiento_y_exploracion_de_los_datos\02_Manipulacion_de_datos_Pandas\.venv\Lib\site-packages\numpy\_utils\_inspect.py:80, in getargs(co)
#      78 nargs = co.co_argcount
#      79 names = co.co_varnames
# ---> 80 args = list(names[:nargs])
#      82 # The following acrobatics are for anonymous (tuple) arguments.
#      83 # Which we do not need to support, so remove to avoid importing
#      84 # the dis module.
#      85 for i in range(nargs):
#
# KeyboardInterrupt:

# %%
# Crear un DataFrame apartir de un diccionario

data = {
    'Nombre' : ['Ana', 'Luis', 'Carlos', 'Lucia', 'Martha', 'Jorge', 'Sofia'],
    'Edad' : [23, 35, 45, 25, 30, 28, 32],
    'Ciudad' : ['CDMX', 'Guadalajara', 'Monterrey', 'CDMX', 'Puebla', 'CDMX', 'Guadalajara'],
    'Salario' : [12000, 15000, 18000, 12500, 14000, 13000, 15500],
    'Departamento' :  ['Ventas', 'Marketing', 'Ventas', 'TI', 'TI', 'Marketing', 'Ventas']
}

# %%
df = pd.DataFrame(data)
df
# Out:
#    Nombre  Edad       Ciudad  Salario Departamento
# 0     Ana    23         CDMX    12000       Ventas
# 1    Luis    35  Guadalajara    15000    Marketing
# 2  Carlos    45    Monterrey    18000       Ventas
# 3   Lucia    25         CDMX    12500           TI
# 4  Martha    30       Puebla    14000           TI
# 5   Jorge    28         CDMX    13000    Marketing
# 6   Sofia    32  Guadalajara    15500       Ventas

# %% [markdown]
# ## 2. Estructura y Resumen del DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Nombre        7 non-null      object
#  1   Edad          7 non-null      int64
#  2   Ciudad        7 non-null      object
#  3   Salario       7 non-null      int64
#  4   Departamento  7 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 412.0+ bytes

# %%
df.describe()
# Out:
#             Edad       Salario
# count   7.000000      7.000000
# mean   31.142857  14285.714286
# std     7.335498   2078.804602
# min    23.000000  12000.000000
# 25%    26.500000  12750.000000
# 50%    30.000000  14000.000000
# 75%    33.500000  15250.000000
# max    45.000000  18000.000000

# %%
# Muestra el Tamaño del Data Frame
df.shape
# Out:
# (7, 5)

# %%
# Muestra el numero de filas
df.shape[0]
# Out:
# 7

# %%
# Muestra el numero de columnas
df.shape[1]
# Out:
# 5

# %%
# Muestra los tipos de las columnas
df.dtypes
# Out:
# Nombre          object
# Edad             int64
# Ciudad          object
# Salario          int64
# Departamento    object
# dtype: object

# %%
# Columnas
df.columns
# Out:
# Index(['Nombre', 'Edad', 'Ciudad', 'Salario', 'Departamento'], dtype='object')

# %%
# Los Indices
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %% [markdown]
# ## 3. Seleccion de Columnas y Filas

# %%
# Selecciona solo la columna de Edad y muestra los datos dentro de ella 
df['Edad']
# Out:
# 0    23
# 1    35
# 2    45
# 3    25
# 4    30
# 5    28
# 6    32
# Name: Edad, dtype: int64

# %%
type(df['Edad'])
# Out:
# pandas.core.series.Series

# %%
df[['Edad']]
# Out:
#    Edad
# 0    23
# 1    35
# 2    45
# 3    25
# 4    30
# 5    28
# 6    32

# %%
type(df[['Edad']])
# Out:
# pandas.core.frame.DataFrame

# %%
df['Salario']
# Out:
# 0    12000
# 1    15000
# 2    18000
# 3    12500
# 4    14000
# 5    13000
# 6    15500
# Name: Salario, dtype: int64

# %%
df[['Nombre', 'Salario', 'Departamento']]
# Out:
#    Nombre  Salario Departamento
# 0     Ana    12000       Ventas
# 1    Luis    15000    Marketing
# 2  Carlos    18000       Ventas
# 3   Lucia    12500           TI
# 4  Martha    14000           TI
# 5   Jorge    13000    Marketing
# 6   Sofia    15500       Ventas

# %% [markdown]
# ## 4. Filtrado de Filas

# %%
# Filtrar todas las filas que la ciudad sea CDMX
df['Ciudad'] == 'CDMX'
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# Name: Ciudad, dtype: bool

# %%
# Filtrar todas las filas que la ciudad sea CDMX
df[df['Ciudad'] == 'CDMX']
# Out:
#   Nombre  Edad Ciudad  Salario Departamento
# 0    Ana    23   CDMX    12000       Ventas
# 3  Lucia    25   CDMX    12500           TI
# 5  Jorge    28   CDMX    13000    Marketing

# %%
df[df['Ciudad'] == 'CDMX'][['Nombre', 'Ciudad', 'Salario']]
# Out:
#   Nombre Ciudad  Salario
# 0    Ana   CDMX    12000
# 3  Lucia   CDMX    12500
# 5  Jorge   CDMX    13000

# %%
df_CDMX = df[df['Ciudad'] == 'CDMX']

# %%
df_CDMX[['Nombre', 'Ciudad', 'Salario']]
# Out:
#   Nombre Ciudad  Salario
# 0    Ana   CDMX    12000
# 3  Lucia   CDMX    12500
# 5  Jorge   CDMX    13000

# %%
# Mostrar todos las filas de la ciudad de mexico y del departamento de TI
df[(df['Ciudad'] == 'CDMX') & (df['Departamento'] == 'TI')]
# Out:
#   Nombre  Edad Ciudad  Salario Departamento
# 3  Lucia    25   CDMX    12500           TI

# %% [markdown]
# # Mostrar todos las filas de la ciudad de mexico o del departamento de TI

# %%
df[(df['Ciudad'] == 'CDMX') | (df['Departamento'] == 'TI')]
# Out:
#    Nombre  Edad  Ciudad  Salario Departamento
# 0     Ana    23    CDMX    12000       Ventas
# 3   Lucia    25    CDMX    12500           TI
# 4  Martha    30  Puebla    14000           TI
# 5   Jorge    28    CDMX    13000    Marketing

# %% [markdown]
# ## 5. Ordenar Filas

# %%
# Ordena por salario de Forma Ascendente (A-Z, 0-9)
df.sort_values(by='Salario', ascending= True)
# Out:
#    Nombre  Edad       Ciudad  Salario Departamento
# 0     Ana    23         CDMX    12000       Ventas
# 3   Lucia    25         CDMX    12500           TI
# 5   Jorge    28         CDMX    13000    Marketing
# 4  Martha    30       Puebla    14000           TI
# 1    Luis    35  Guadalajara    15000    Marketing
# 6   Sofia    32  Guadalajara    15500       Ventas
# 2  Carlos    45    Monterrey    18000       Ventas

# %%
# Ordena por salario de Forma Descendente (A-Z, 0-9)
df.sort_values(by='Salario', ascending= False)
# Out:
#    Nombre  Edad       Ciudad  Salario Departamento
# 2  Carlos    45    Monterrey    18000       Ventas
# 6   Sofia    32  Guadalajara    15500       Ventas
# 1    Luis    35  Guadalajara    15000    Marketing
# 4  Martha    30       Puebla    14000           TI
# 5   Jorge    28         CDMX    13000    Marketing
# 3   Lucia    25         CDMX    12500           TI
# 0     Ana    23         CDMX    12000       Ventas

# %%
# Ordenar por el Salario y la Ciudad
df.sort_values(by=['Ciudad', 'Salario'])
# Out:
#    Nombre  Edad       Ciudad  Salario Departamento
# 0     Ana    23         CDMX    12000       Ventas
# 3   Lucia    25         CDMX    12500           TI
# 5   Jorge    28         CDMX    13000    Marketing
# 1    Luis    35  Guadalajara    15000    Marketing
# 6   Sofia    32  Guadalajara    15500       Ventas
# 2  Carlos    45    Monterrey    18000       Ventas
# 4  Martha    30       Puebla    14000           TI

# %%
# Ordenar por el Salario y la Ciudad
df.sort_values(by=['Ciudad', 'Salario'], ascending=[True, True])
# Out:
#    Nombre  Edad       Ciudad  Salario Departamento
# 0     Ana    23         CDMX    12000       Ventas
# 3   Lucia    25         CDMX    12500           TI
# 5   Jorge    28         CDMX    13000    Marketing
# 1    Luis    35  Guadalajara    15000    Marketing
# 6   Sofia    32  Guadalajara    15500       Ventas
# 2  Carlos    45    Monterrey    18000       Ventas
# 4  Martha    30       Puebla    14000           TI

# %%
# Ordenar por el Salario y la Ciudad
df.sort_values(by=['Ciudad', 'Salario'], ascending=[True, False])
# Out:
#    Nombre  Edad       Ciudad  Salario Departamento
# 5   Jorge    28         CDMX    13000    Marketing
# 3   Lucia    25         CDMX    12500           TI
# 0     Ana    23         CDMX    12000       Ventas
# 6   Sofia    32  Guadalajara    15500       Ventas
# 1    Luis    35  Guadalajara    15000    Marketing
# 2  Carlos    45    Monterrey    18000       Ventas
# 4  Martha    30       Puebla    14000           TI

# %%
# Ordenar por el Salario y la Ciudad
df.sort_values(by=['Ciudad', 'Salario'], ascending=[False, True])
# Out:
#    Nombre  Edad       Ciudad  Salario Departamento
# 4  Martha    30       Puebla    14000           TI
# 2  Carlos    45    Monterrey    18000       Ventas
# 1    Luis    35  Guadalajara    15000    Marketing
# 6   Sofia    32  Guadalajara    15500       Ventas
# 0     Ana    23         CDMX    12000       Ventas
# 3   Lucia    25         CDMX    12500           TI
# 5   Jorge    28         CDMX    13000    Marketing

# %%
# Ordenar por el Salario y la Ciudad
df.sort_values(by=['Ciudad', 'Salario'], ascending=[False, False])
# Out:
#    Nombre  Edad       Ciudad  Salario Departamento
# 4  Martha    30       Puebla    14000           TI
# 2  Carlos    45    Monterrey    18000       Ventas
# 6   Sofia    32  Guadalajara    15500       Ventas
# 1    Luis    35  Guadalajara    15000    Marketing
# 5   Jorge    28         CDMX    13000    Marketing
# 3   Lucia    25         CDMX    12500           TI
# 0     Ana    23         CDMX    12000       Ventas

# %%
df[(df['Ciudad'] == 'CDMX') | (df['Departamento'] == 'TI')].sort_values(by=['Edad', 'Departamento'], ascending=[True, False])
# Out:
#    Nombre  Edad  Ciudad  Salario Departamento
# 0     Ana    23    CDMX    12000       Ventas
# 3   Lucia    25    CDMX    12500           TI
# 5   Jorge    28    CDMX    13000    Marketing
# 4  Martha    30  Puebla    14000           TI

# %% [markdown]
# ## 6. Crear Nuevas Columnas

# %%
df['Salario_Anual'] = df['Salario'] * 12

# %%
df
# Out:
#    Nombre  Edad       Ciudad  Salario Departamento  Salario_Anual
# 0     Ana    23         CDMX    12000       Ventas         144000
# 1    Luis    35  Guadalajara    15000    Marketing         180000
# 2  Carlos    45    Monterrey    18000       Ventas         216000
# 3   Lucia    25         CDMX    12500           TI         150000
# 4  Martha    30       Puebla    14000           TI         168000
# 5   Jorge    28         CDMX    13000    Marketing         156000
# 6   Sofia    32  Guadalajara    15500       Ventas         186000
